# %%
import pandas as pd
import scraper
import importlib
importlib.reload(scraper) # every run
# Out:
# <module 'scraper' from 'c:\\Users\\arnav\\Documents\\GitHub\\Manchester-United-Dashboard\\scraper.py'>

# %%
years = list(range(2010,2024,1))
scraper.createOutputFolder()
for year in years:
    df = scraper.getDataForYear(year)
    scraper.createCSV(df, year)

# %%
df = pd.read_csv('data\ManchesterUnited2010-2011.csv')
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\arnav\AppData\Local\Temp\ipykernel_33000\3523700876.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv('data\ManchesterUnited2010-2011.csv')
#                Player   Nation    Pos   Age  MP   Min   Gls   Ast    G+A   PK
# 0       Nemanja Vidić   rs SRB     DF  28.0  35  3115   5.0   1.0    6.0  0.0
# 1        Patrice Evra   fr FRA     DF  29.0  35  2961   1.0   1.0    2.0  0.0
# 2   Edwin van der Sar   nl NED     GK  39.0  33  2970   0.0   1.0    1.0  0.0
# 3                Nani   pt POR  FW,MF  23.0  33  2659   9.0  14.0   23.0  0.0
# 4        Wayne Rooney  eng ENG  FW,MF  24.0  28  2225  11.0  11.0   22.0  3.0
# 5    Dimitar Berbatov   bg BUL     FW  29.0  32  2208  20.0   4.0   24.0  0.0
# 6     Darren Fletcher  sct SCO     MF  26.0  26  2109   2.0   6.0    8.0  0.0
# 7     Michael Carrick  eng ENG     MF  29.0  28  1972   0.0   0.0    0.0  0.0
# 8       Rio Ferdinand  eng ENG     DF  31.0  19  1710   0.0   0.0    0.0  0.0
# 9          Ryan Giggs  wls WAL  FW,MF  36.0  25  1676   2.0   6.0    8.0  0.0
# 10        John O'Shea   ie IRL  DF,MF  29.0  20  1541   0.0   3.0    3.0  0.0
# 11       Paul Scholes  eng ENG     MF  35.0  22  1537   1.0   3.0    4.0  0.0
# 12   Javier Hernández   mx MEX     FW  22.0  27  1492  13.0   1.0   14.0  0.0
# 13             Rafael   br BRA  DF,MF  20.0  16  1198   0.0   1.0    1.0  0.0
# 14           Anderson   br BRA     MF  22.0  18  1182   1.0   2.0    3.0  0.0
# 15       Park Ji-sung   kr KOR     MF  29.0  15  1080   5.0   3.0    8.0  0.0
# 16     Chris Smalling  eng ENG     DF  20.0  16  1086   0.0   0.0    0.0  0.0
# 17        Jonny Evans  nir NIR     DF  22.0  13  1005   0.0   0.0    0.0  0.0
# 18   Antonio Valencia   ec ECU  DF,MF  24.0  10   742   1.0   2.0    3.0  0.0
# 19      Darron Gibson   ie IRL     MF  22.0  12   656   0.0   1.0    1.0  0.0
# 20              Fábio   br BRA     DF  20.0  11   555   1.0   0.0    1.0  0.0
# 21    Tomasz Kuszczak   pl POL     GK  28.0   5   450   0.0   0.0    0.0  0.0
# 22          Wes Brown  eng ENG     DF  30.0   7   429   0.0   0.0    0.0  0.0
# 23    Gabriel Obertan   fr FRA  FW,MF  21.0   7   284   0.0   0.0    0.0  0.0
# 24       Gary Neville  eng ENG     DF  35.0   3   205   0.0   0.0    0.0  0.0
# 25   Federico Macheda   it ITA     FW  18.0   7   220   1.0   0.0    1.0  0.0
# 26       Michael Owen  eng ENG     FW  30.0  11   238   2.0   0.0    2.0  0.0
# 27    Owen Hargreaves  eng ENG     MF  29.0   1     9   0.0   0.0    0.0  0.0
# 28               Bebé   cv CPV  FW,MF  20.0   2    75   0.0   0.0    0.0  0.0
# 29        Squad Total      NaN    NaN  28.3  38  3420  75.0  59.0  134.0  3.0
# 30     Opponent Total      NaN    NaN  27.0  38  3420   NaN   NaN    NaN  NaN
